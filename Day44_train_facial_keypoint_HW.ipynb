# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2

# %%
# !pip install keras==2.2.4
# !pip install keras==2.2.4
# Out:
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 12.3MB/s
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Installing collected packages: keras
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.4.3
# Collecting keras==2.2.4
#   Using cached https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Installing collected packages: keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.2.4

# %%
import os
from google.colab import drive 
drive.mount('/content/drive') # 將 google drive 掛載在 colob，
# %cd "/content/drive/MyDrive/Colab/1st-DL-CVMarathon/Day042.Workdir"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab/1st-DL-CVMarathon/Day042.Workdir

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, 
                       epochs=150,
                       verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 0s 283us/step - loss: 3.6899e-04 - val_loss: 9.5011e-04
#
# Epoch 00001: val_loss improved from 0.00095 to 0.00095, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 3.5547e-04 - val_loss: 9.0154e-04
#
# Epoch 00002: val_loss improved from 0.00095 to 0.00090, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 3.4129e-04 - val_loss: 8.8366e-04
#
# Epoch 00003: val_loss improved from 0.00090 to 0.00088, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 3.2886e-04 - val_loss: 9.0373e-04
#
# Epoch 00004: val_loss did not improve from 0.00088
# Epoch 5/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 3.2028e-04 - val_loss: 8.3032e-04
#
# Epoch 00005: val_loss improved from 0.00088 to 0.00083, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 2.9523e-04 - val_loss: 8.3941e-04
#
# Epoch 00006: val_loss did not improve from 0.00083
# Epoch 7/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 2.8040e-04 - val_loss: 8.5789e-04
#
# Epoch 00007: val_loss did not improve from 0.00083
# Epoch 8/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 2.7947e-04 - val_loss: 8.2150e-04
#
# Epoch 00008: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 2.7307e-04 - val_loss: 8.1026e-04
#
# Epoch 00009: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 2.6460e-04 - val_loss: 8.1288e-04
#
# Epoch 00010: val_loss did not improve from 0.00081
# Epoch 11/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 2.5668e-04 - val_loss: 8.0688e-04
#
# Epoch 00011: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 2.5622e-04 - val_loss: 7.9912e-04
#
# Epoch 00012: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 2.5098e-04 - val_loss: 7.8010e-04
#
# Epoch 00013: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 2.3747e-04 - val_loss: 7.8010e-04
#
# Epoch 00014: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 2.3279e-04 - val_loss: 7.8963e-04
#
# Epoch 00015: val_loss did not improve from 0.00078
# Epoch 16/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 2.2712e-04 - val_loss: 7.8741e-04
#
# Epoch 00016: val_loss did not improve from 0.00078
# Epoch 17/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 2.1670e-04 - val_loss: 7.7745e-04
#
# Epoch 00017: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 2.1326e-04 - val_loss: 7.8859e-04
#
# Epoch 00018: val_loss did not improve from 0.00078
# Epoch 19/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 2.1348e-04 - val_loss: 7.9552e-04
#
# Epoch 00019: val_loss did not improve from 0.00078
# Epoch 20/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 2.1500e-04 - val_loss: 7.6517e-04
#
# Epoch 00020: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 2.0572e-04 - val_loss: 7.6931e-04
#
# Epoch 00021: val_loss did not improve from 0.00077
# Epoch 22/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 2.1005e-04 - val_loss: 8.7294e-04
#
# Epoch 00022: val_loss did not improve from 0.00077
# Epoch 23/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 2.1356e-04 - val_loss: 7.8293e-04
#
# Epoch 00023: val_loss did not improve from 0.00077
# Epoch 24/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.0206e-04 - val_loss: 7.5855e-04
#
# Epoch 00024: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 2.0004e-04 - val_loss: 7.4805e-04
#
# Epoch 00025: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.8698e-04 - val_loss: 7.5220e-04
#
# Epoch 00026: val_loss did not improve from 0.00075
# Epoch 27/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.8644e-04 - val_loss: 7.6134e-04
#
# Epoch 00027: val_loss did not improve from 0.00075
# Epoch 28/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.8590e-04 - val_loss: 7.5669e-04
#
# Epoch 00028: val_loss did not improve from 0.00075
# Epoch 29/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.8288e-04 - val_loss: 8.0032e-04
#
# Epoch 00029: val_loss did not improve from 0.00075
# Epoch 30/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 1.8706e-04 - val_loss: 7.4630e-04
#
# Epoch 00030: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 1.8221e-04 - val_loss: 7.5427e-04
#
# Epoch 00031: val_loss did not improve from 0.00075
# Epoch 32/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.8284e-04 - val_loss: 7.4681e-04
#
# Epoch 00032: val_loss did not improve from 0.00075
# Epoch 33/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.7359e-04 - val_loss: 8.1989e-04
#
# Epoch 00033: val_loss did not improve from 0.00075
# Epoch 34/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.8689e-04 - val_loss: 7.7081e-04
#
# Epoch 00034: val_loss did not improve from 0.00075
# Epoch 35/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.7634e-04 - val_loss: 7.8861e-04
#
# Epoch 00035: val_loss did not improve from 0.00075
# Epoch 36/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.7095e-04 - val_loss: 7.7468e-04
#
# Epoch 00036: val_loss did not improve from 0.00075
# Epoch 37/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.6746e-04 - val_loss: 7.7172e-04
#
# Epoch 00037: val_loss did not improve from 0.00075
# Epoch 38/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.6738e-04 - val_loss: 7.5594e-04
#
# Epoch 00038: val_loss did not improve from 0.00075
# Epoch 39/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.6476e-04 - val_loss: 7.2130e-04
#
# Epoch 00039: val_loss improved from 0.00075 to 0.00072, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.5783e-04 - val_loss: 7.3616e-04
#
# Epoch 00040: val_loss did not improve from 0.00072
# Epoch 41/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.6723e-04 - val_loss: 7.2827e-04
#
# Epoch 00041: val_loss did not improve from 0.00072
# Epoch 42/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.6135e-04 - val_loss: 7.4446e-04
#
# Epoch 00042: val_loss did not improve from 0.00072
# Epoch 43/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.5578e-04 - val_loss: 7.3629e-04
#
# Epoch 00043: val_loss did not improve from 0.00072
# Epoch 44/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.5197e-04 - val_loss: 7.3015e-04
#
# Epoch 00044: val_loss did not improve from 0.00072
# Epoch 45/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.5201e-04 - val_loss: 7.5787e-04
#
# Epoch 00045: val_loss did not improve from 0.00072
# Epoch 46/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.6111e-04 - val_loss: 7.4683e-04
#
# Epoch 00046: val_loss did not improve from 0.00072
# Epoch 47/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.5030e-04 - val_loss: 7.7984e-04
#
# Epoch 00047: val_loss did not improve from 0.00072
# Epoch 48/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.4927e-04 - val_loss: 7.2590e-04
#
# Epoch 00048: val_loss did not improve from 0.00072
# Epoch 49/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.4781e-04 - val_loss: 7.4296e-04
#
# Epoch 00049: val_loss did not improve from 0.00072
# Epoch 50/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.4618e-04 - val_loss: 7.1860e-04
#
# Epoch 00050: val_loss improved from 0.00072 to 0.00072, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.4151e-04 - val_loss: 7.1589e-04
#
# Epoch 00051: val_loss improved from 0.00072 to 0.00072, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.4502e-04 - val_loss: 7.1329e-04
#
# Epoch 00052: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.4251e-04 - val_loss: 7.4002e-04
#
# Epoch 00053: val_loss did not improve from 0.00071
# Epoch 54/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.3958e-04 - val_loss: 7.2613e-04
#
# Epoch 00054: val_loss did not improve from 0.00071
# Epoch 55/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.3896e-04 - val_loss: 7.4017e-04
#
# Epoch 00055: val_loss did not improve from 0.00071
# Epoch 56/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.3903e-04 - val_loss: 7.5126e-04
#
# Epoch 00056: val_loss did not improve from 0.00071
# Epoch 57/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.3561e-04 - val_loss: 7.0404e-04
#
# Epoch 00057: val_loss improved from 0.00071 to 0.00070, saving model to best_weights.h5
# Epoch 58/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.3154e-04 - val_loss: 7.2782e-04
#
# Epoch 00058: val_loss did not improve from 0.00070
# Epoch 59/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.3522e-04 - val_loss: 7.3556e-04
#
# Epoch 00059: val_loss did not improve from 0.00070
# Epoch 60/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.3375e-04 - val_loss: 7.4093e-04
#
# Epoch 00060: val_loss did not improve from 0.00070
# Epoch 61/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.3098e-04 - val_loss: 7.2987e-04
#
# Epoch 00061: val_loss did not improve from 0.00070
# Epoch 62/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.3552e-04 - val_loss: 7.1718e-04
#
# Epoch 00062: val_loss did not improve from 0.00070
# Epoch 63/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.3446e-04 - val_loss: 7.5572e-04
#
# Epoch 00063: val_loss did not improve from 0.00070
# Epoch 64/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.2895e-04 - val_loss: 7.4571e-04
#
# Epoch 00064: val_loss did not improve from 0.00070
# Epoch 65/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.2625e-04 - val_loss: 7.6808e-04
#
# Epoch 00065: val_loss did not improve from 0.00070
# Epoch 66/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 1.2684e-04 - val_loss: 7.5882e-04
#
# Epoch 00066: val_loss did not improve from 0.00070
# Epoch 67/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.2520e-04 - val_loss: 7.2325e-04
#
# Epoch 00067: val_loss did not improve from 0.00070
# Epoch 68/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.2378e-04 - val_loss: 7.2099e-04
#
# Epoch 00068: val_loss did not improve from 0.00070
# Epoch 69/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.2421e-04 - val_loss: 7.2814e-04
#
# Epoch 00069: val_loss did not improve from 0.00070
# Epoch 70/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 1.2200e-04 - val_loss: 7.2961e-04
#
# Epoch 00070: val_loss did not improve from 0.00070
# Epoch 71/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 1.2168e-04 - val_loss: 7.1056e-04
#
# Epoch 00071: val_loss did not improve from 0.00070
# Epoch 72/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.1582e-04 - val_loss: 7.4958e-04
#
# Epoch 00072: val_loss did not improve from 0.00070
# Epoch 73/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.1763e-04 - val_loss: 7.4772e-04
#
# Epoch 00073: val_loss did not improve from 0.00070
# Epoch 74/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.2011e-04 - val_loss: 7.6199e-04
#
# Epoch 00074: val_loss did not improve from 0.00070
# Epoch 75/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.1743e-04 - val_loss: 7.1015e-04
#
# Epoch 00075: val_loss did not improve from 0.00070
# Epoch 76/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.1628e-04 - val_loss: 7.5784e-04
#
# Epoch 00076: val_loss did not improve from 0.00070
# Epoch 77/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.0961e-04 - val_loss: 7.3763e-04
#
# Epoch 00077: val_loss did not improve from 0.00070
# Epoch 78/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.1105e-04 - val_loss: 7.4649e-04
#
# Epoch 00078: val_loss did not improve from 0.00070
# Epoch 79/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.1375e-04 - val_loss: 7.2662e-04
#
# Epoch 00079: val_loss did not improve from 0.00070
# Epoch 80/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.1355e-04 - val_loss: 7.3044e-04
#
# Epoch 00080: val_loss did not improve from 0.00070
# Epoch 81/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.1081e-04 - val_loss: 7.4398e-04
#
# Epoch 00081: val_loss did not improve from 0.00070
# Epoch 82/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.1174e-04 - val_loss: 7.3553e-04
#
# Epoch 00082: val_loss did not improve from 0.00070
# Epoch 83/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.0953e-04 - val_loss: 7.4788e-04
#
# Epoch 00083: val_loss did not improve from 0.00070
# Epoch 84/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.0599e-04 - val_loss: 7.3307e-04
#
# Epoch 00084: val_loss did not improve from 0.00070
# Epoch 85/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 1.0610e-04 - val_loss: 7.3731e-04
#
# Epoch 00085: val_loss did not improve from 0.00070
# Epoch 86/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 1.0783e-04 - val_loss: 7.4911e-04
#
# Epoch 00086: val_loss did not improve from 0.00070
# Epoch 87/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.0633e-04 - val_loss: 7.4223e-04
#
# Epoch 00087: val_loss did not improve from 0.00070
# Epoch 88/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.0652e-04 - val_loss: 7.4595e-04
#
# Epoch 00088: val_loss did not improve from 0.00070
# Epoch 89/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.0302e-04 - val_loss: 7.2335e-04
#
# Epoch 00089: val_loss did not improve from 0.00070
# Epoch 90/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 1.0563e-04 - val_loss: 7.4690e-04
#
# Epoch 00090: val_loss did not improve from 0.00070
# Epoch 91/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.0507e-04 - val_loss: 7.3796e-04
#
# Epoch 00091: val_loss did not improve from 0.00070
# Epoch 92/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 1.0540e-04 - val_loss: 7.1789e-04
#
# Epoch 00092: val_loss did not improve from 0.00070
# Epoch 93/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.0337e-04 - val_loss: 7.2386e-04
#
# Epoch 00093: val_loss did not improve from 0.00070
# Epoch 94/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 1.0405e-04 - val_loss: 7.1676e-04
#
# Epoch 00094: val_loss did not improve from 0.00070
# Epoch 95/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 1.0035e-04 - val_loss: 7.2733e-04
#
# Epoch 00095: val_loss did not improve from 0.00070
# Epoch 96/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.0077e-04 - val_loss: 7.3452e-04
#
# Epoch 00096: val_loss did not improve from 0.00070
# Epoch 97/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 9.9865e-05 - val_loss: 7.5209e-04
#
# Epoch 00097: val_loss did not improve from 0.00070
# Epoch 98/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.0027e-04 - val_loss: 7.1444e-04
#
# Epoch 00098: val_loss did not improve from 0.00070
# Epoch 99/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 9.7118e-05 - val_loss: 7.3997e-04
#
# Epoch 00099: val_loss did not improve from 0.00070
# Epoch 100/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 9.9750e-05 - val_loss: 7.1512e-04
#
# Epoch 00100: val_loss did not improve from 0.00070
# Epoch 101/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 9.8362e-05 - val_loss: 7.4152e-04
#
# Epoch 00101: val_loss did not improve from 0.00070
# Epoch 102/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 9.6585e-05 - val_loss: 7.4588e-04
#
# Epoch 00102: val_loss did not improve from 0.00070
# Epoch 103/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 9.5955e-05 - val_loss: 7.3193e-04
#
# Epoch 00103: val_loss did not improve from 0.00070
# Epoch 104/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 9.6700e-05 - val_loss: 7.7038e-04
#
# Epoch 00104: val_loss did not improve from 0.00070
# Epoch 105/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 9.5981e-05 - val_loss: 7.4203e-04
#
# Epoch 00105: val_loss did not improve from 0.00070
# Epoch 106/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 9.3345e-05 - val_loss: 7.3278e-04
#
# Epoch 00106: val_loss did not improve from 0.00070
# Epoch 107/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 9.6228e-05 - val_loss: 7.1260e-04
#
# Epoch 00107: val_loss did not improve from 0.00070
# Epoch 108/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 9.7607e-05 - val_loss: 7.3858e-04
#
# Epoch 00108: val_loss did not improve from 0.00070
# Epoch 109/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 9.5650e-05 - val_loss: 7.5464e-04
#
# Epoch 00109: val_loss did not improve from 0.00070
# Epoch 110/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 9.3249e-05 - val_loss: 7.4537e-04
#
# Epoch 00110: val_loss did not improve from 0.00070
# Epoch 111/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 9.2005e-05 - val_loss: 7.4015e-04
#
# Epoch 00111: val_loss did not improve from 0.00070
# Epoch 112/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 9.1601e-05 - val_loss: 7.2944e-04
#
# Epoch 00112: val_loss did not improve from 0.00070
# Epoch 113/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 9.2532e-05 - val_loss: 7.6188e-04
#
# Epoch 00113: val_loss did not improve from 0.00070
# Epoch 114/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 8.9827e-05 - val_loss: 7.3923e-04
#
# Epoch 00114: val_loss did not improve from 0.00070
# Epoch 115/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 8.9134e-05 - val_loss: 7.4113e-04
#
# Epoch 00115: val_loss did not improve from 0.00070
# Epoch 116/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 9.0404e-05 - val_loss: 7.4478e-04
#
# Epoch 00116: val_loss did not improve from 0.00070
# Epoch 117/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 9.1374e-05 - val_loss: 7.3809e-04
#
# Epoch 00117: val_loss did not improve from 0.00070
# Epoch 118/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 8.9778e-05 - val_loss: 7.4020e-04
#
# Epoch 00118: val_loss did not improve from 0.00070
# Epoch 119/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 8.5872e-05 - val_loss: 7.6424e-04
#
# Epoch 00119: val_loss did not improve from 0.00070
# Epoch 120/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 8.5382e-05 - val_loss: 7.4461e-04
#
# Epoch 00120: val_loss did not improve from 0.00070
# Epoch 121/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 8.9031e-05 - val_loss: 7.5005e-04
#
# Epoch 00121: val_loss did not improve from 0.00070
# Epoch 122/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 8.7049e-05 - val_loss: 8.0315e-04
#
# Epoch 00122: val_loss did not improve from 0.00070
# Epoch 123/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 8.5114e-05 - val_loss: 7.2172e-04
#
# Epoch 00123: val_loss did not improve from 0.00070
# Epoch 124/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 8.6130e-05 - val_loss: 7.3634e-04
#
# Epoch 00124: val_loss did not improve from 0.00070
# Epoch 125/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 8.1903e-05 - val_loss: 7.6439e-04
#
# Epoch 00125: val_loss did not improve from 0.00070
# Epoch 126/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 8.6375e-05 - val_loss: 7.6202e-04
#
# Epoch 00126: val_loss did not improve from 0.00070
# Epoch 127/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 8.4986e-05 - val_loss: 7.1941e-04
#
# Epoch 00127: val_loss did not improve from 0.00070
# Epoch 128/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 8.4692e-05 - val_loss: 7.4886e-04
#
# Epoch 00128: val_loss did not improve from 0.00070
# Epoch 129/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 8.4156e-05 - val_loss: 7.6207e-04
#
# Epoch 00129: val_loss did not improve from 0.00070
# Epoch 130/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 8.5145e-05 - val_loss: 7.8834e-04
#
# Epoch 00130: val_loss did not improve from 0.00070
# Epoch 131/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 8.3003e-05 - val_loss: 7.4399e-04
#
# Epoch 00131: val_loss did not improve from 0.00070
# Epoch 132/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 8.5602e-05 - val_loss: 7.6305e-04
#
# Epoch 00132: val_loss did not improve from 0.00070
# Epoch 133/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 8.2791e-05 - val_loss: 7.3518e-04
#
# Epoch 00133: val_loss did not improve from 0.00070
# Epoch 134/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 8.0500e-05 - val_loss: 7.6840e-04
#
# Epoch 00134: val_loss did not improve from 0.00070
# Epoch 135/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 8.0790e-05 - val_loss: 7.4600e-04
#
# Epoch 00135: val_loss did not improve from 0.00070
# Epoch 136/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 7.9778e-05 - val_loss: 7.3108e-04
#
# Epoch 00136: val_loss did not improve from 0.00070
# Epoch 137/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 7.8159e-05 - val_loss: 7.4483e-04
#
# Epoch 00137: val_loss did not improve from 0.00070
# Epoch 138/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 7.9227e-05 - val_loss: 7.5492e-04
#
# Epoch 00138: val_loss did not improve from 0.00070
# Epoch 139/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 7.6263e-05 - val_loss: 7.3779e-04
#
# Epoch 00139: val_loss did not improve from 0.00070
# Epoch 140/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 7.8406e-05 - val_loss: 7.4479e-04
#
# Epoch 00140: val_loss did not improve from 0.00070
# Epoch 141/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 7.9775e-05 - val_loss: 7.3871e-04
#
# Epoch 00141: val_loss did not improve from 0.00070
# Epoch 142/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 7.7591e-05 - val_loss: 7.4270e-04
#
# Epoch 00142: val_loss did not improve from 0.00070
# Epoch 143/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 7.8580e-05 - val_loss: 7.8096e-04
#
# Epoch 00143: val_loss did not improve from 0.00070
# Epoch 144/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 8.0052e-05 - val_loss: 7.4590e-04
#
# Epoch 00144: val_loss did not improve from 0.00070
# Epoch 145/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 7.8255e-05 - val_loss: 7.4159e-04
#
# Epoch 00145: val_loss did not improve from 0.00070
# Epoch 146/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 7.8103e-05 - val_loss: 7.2901e-04
#
# Epoch 00146: val_loss did not improve from 0.00070
# Epoch 147/150
# 1712/1712 [==============================] - 0s 236us/step - loss: 7.7856e-05 - val_loss: 7.4898e-04
#
# Epoch 00147: val_loss did not improve from 0.00070
# Epoch 148/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 7.5249e-05 - val_loss: 7.4765e-04
#
# Epoch 00148: val_loss did not improve from 0.00070
# Epoch 149/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 7.7148e-05 - val_loss: 7.2437e-04
#
# Epoch 00149: val_loss did not improve from 0.00070
# Epoch 150/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 7.7814e-05 - val_loss: 7.4378e-04
#
# Epoch 00150: val_loss did not improve from 0.00070

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 0.0063 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00195, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00195 to 0.00187, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00187 to 0.00175, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 9.3905e-04 - val_loss: 0.0015
#
# Epoch 00004: val_loss improved from 0.00175 to 0.00150, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 7.3166e-04 - val_loss: 0.0013
#
# Epoch 00005: val_loss improved from 0.00150 to 0.00128, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 6.0590e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00128 to 0.00110, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 5.1260e-04 - val_loss: 9.6666e-04
#
# Epoch 00007: val_loss improved from 0.00110 to 0.00097, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 4.6318e-04 - val_loss: 8.9743e-04
#
# Epoch 00008: val_loss improved from 0.00097 to 0.00090, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 4.1872e-04 - val_loss: 9.1950e-04
#
# Epoch 00009: val_loss did not improve from 0.00090
# Epoch 10/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 3.8887e-04 - val_loss: 8.3181e-04
#
# Epoch 00010: val_loss improved from 0.00090 to 0.00083, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 3.7096e-04 - val_loss: 7.7831e-04
#
# Epoch 00011: val_loss improved from 0.00083 to 0.00078, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 3.4382e-04 - val_loss: 7.9121e-04
#
# Epoch 00012: val_loss did not improve from 0.00078
# Epoch 13/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 3.3666e-04 - val_loss: 7.5912e-04
#
# Epoch 00013: val_loss improved from 0.00078 to 0.00076, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 3.1751e-04 - val_loss: 7.7522e-04
#
# Epoch 00014: val_loss did not improve from 0.00076
# Epoch 15/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 3.0348e-04 - val_loss: 7.3419e-04
#
# Epoch 00015: val_loss improved from 0.00076 to 0.00073, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 2.8644e-04 - val_loss: 7.2016e-04
#
# Epoch 00016: val_loss improved from 0.00073 to 0.00072, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 2.7787e-04 - val_loss: 7.3041e-04
#
# Epoch 00017: val_loss did not improve from 0.00072
# Epoch 18/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 2.7677e-04 - val_loss: 7.5496e-04
#
# Epoch 00018: val_loss did not improve from 0.00072
# Epoch 19/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 2.6096e-04 - val_loss: 6.9720e-04
#
# Epoch 00019: val_loss improved from 0.00072 to 0.00070, saving model to best_weights_augment.h5
# Epoch 20/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 2.5488e-04 - val_loss: 6.7679e-04
#
# Epoch 00020: val_loss improved from 0.00070 to 0.00068, saving model to best_weights_augment.h5
# Epoch 21/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 2.4465e-04 - val_loss: 6.6915e-04
#
# Epoch 00021: val_loss improved from 0.00068 to 0.00067, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 2.4118e-04 - val_loss: 6.9291e-04
#
# Epoch 00022: val_loss did not improve from 0.00067
# Epoch 23/150
# 3424/3424 [==============================] - 1s 229us/step - loss: 2.2835e-04 - val_loss: 7.0483e-04
#
# Epoch 00023: val_loss did not improve from 0.00067
# Epoch 24/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 2.2618e-04 - val_loss: 7.0995e-04
#
# Epoch 00024: val_loss did not improve from 0.00067
# Epoch 25/150
# 3424/3424 [==============================] - 1s 231us/step - loss: 2.1778e-04 - val_loss: 6.6996e-04
#
# Epoch 00025: val_loss did not improve from 0.00067
# Epoch 26/150
# 3424/3424 [==============================] - 1s 230us/step - loss: 2.1499e-04 - val_loss: 6.9222e-04
#
# Epoch 00026: val_loss did not improve from 0.00067
# Epoch 27/150
# 3424/3424 [==============================] - 1s 229us/step - loss: 2.0800e-04 - val_loss: 6.6837e-04
#
# Epoch 00027: val_loss improved from 0.00067 to 0.00067, saving model to best_weights_augment.h5
# Epoch 28/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 2.0712e-04 - val_loss: 6.8323e-04
#
# Epoch 00028: val_loss did not improve from 0.00067
# Epoch 29/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 2.0416e-04 - val_loss: 6.8643e-04
#
# Epoch 00029: val_loss did not improve from 0.00067
# Epoch 30/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 1.9764e-04 - val_loss: 6.4845e-04
#
# Epoch 00030: val_loss improved from 0.00067 to 0.00065, saving model to best_weights_augment.h5
# Epoch 31/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 1.9520e-04 - val_loss: 6.5952e-04
#
# Epoch 00031: val_loss did not improve from 0.00065
# Epoch 32/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.8974e-04 - val_loss: 6.8477e-04
#
# Epoch 00032: val_loss did not improve from 0.00065
# Epoch 33/150
# 3424/3424 [==============================] - 1s 230us/step - loss: 1.8584e-04 - val_loss: 6.7822e-04
#
# Epoch 00033: val_loss did not improve from 0.00065
# Epoch 34/150
# 3424/3424 [==============================] - 1s 231us/step - loss: 1.8339e-04 - val_loss: 6.7573e-04
#
# Epoch 00034: val_loss did not improve from 0.00065
# Epoch 35/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 1.8023e-04 - val_loss: 6.4296e-04
#
# Epoch 00035: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 36/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.8059e-04 - val_loss: 6.5686e-04
#
# Epoch 00036: val_loss did not improve from 0.00064
# Epoch 37/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.7068e-04 - val_loss: 6.4969e-04
#
# Epoch 00037: val_loss did not improve from 0.00064
# Epoch 38/150
# 3424/3424 [==============================] - 1s 227us/step - loss: 1.6770e-04 - val_loss: 7.0042e-04
#
# Epoch 00038: val_loss did not improve from 0.00064
# Epoch 39/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.6601e-04 - val_loss: 6.9052e-04
#
# Epoch 00039: val_loss did not improve from 0.00064
# Epoch 40/150
# 3424/3424 [==============================] - 1s 231us/step - loss: 1.6491e-04 - val_loss: 6.9160e-04
#
# Epoch 00040: val_loss did not improve from 0.00064
# Epoch 41/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 1.6066e-04 - val_loss: 6.3882e-04
#
# Epoch 00041: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 42/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.5906e-04 - val_loss: 6.7246e-04
#
# Epoch 00042: val_loss did not improve from 0.00064
# Epoch 43/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 1.5767e-04 - val_loss: 6.4729e-04
#
# Epoch 00043: val_loss did not improve from 0.00064
# Epoch 44/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 1.5367e-04 - val_loss: 6.6042e-04
#
# Epoch 00044: val_loss did not improve from 0.00064
# Epoch 45/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.4805e-04 - val_loss: 6.6169e-04
#
# Epoch 00045: val_loss did not improve from 0.00064
# Epoch 46/150
# 3424/3424 [==============================] - 1s 230us/step - loss: 1.4802e-04 - val_loss: 6.4709e-04
#
# Epoch 00046: val_loss did not improve from 0.00064
# Epoch 47/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 1.4839e-04 - val_loss: 6.4803e-04
#
# Epoch 00047: val_loss did not improve from 0.00064
# Epoch 48/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 1.4497e-04 - val_loss: 6.5924e-04
#
# Epoch 00048: val_loss did not improve from 0.00064
# Epoch 49/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.4551e-04 - val_loss: 6.4611e-04
#
# Epoch 00049: val_loss did not improve from 0.00064
# Epoch 50/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 1.4193e-04 - val_loss: 6.6103e-04
#
# Epoch 00050: val_loss did not improve from 0.00064
# Epoch 51/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 1.3858e-04 - val_loss: 6.7473e-04
#
# Epoch 00051: val_loss did not improve from 0.00064
# Epoch 52/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.3831e-04 - val_loss: 6.6324e-04
#
# Epoch 00052: val_loss did not improve from 0.00064
# Epoch 53/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.3523e-04 - val_loss: 6.4055e-04
#
# Epoch 00053: val_loss did not improve from 0.00064
# Epoch 54/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.3320e-04 - val_loss: 6.7018e-04
#
# Epoch 00054: val_loss did not improve from 0.00064
# Epoch 55/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.3552e-04 - val_loss: 6.8887e-04
#
# Epoch 00055: val_loss did not improve from 0.00064
# Epoch 56/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 1.3048e-04 - val_loss: 6.6041e-04
#
# Epoch 00056: val_loss did not improve from 0.00064
# Epoch 57/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.2797e-04 - val_loss: 6.4825e-04
#
# Epoch 00057: val_loss did not improve from 0.00064
# Epoch 58/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.3009e-04 - val_loss: 6.4520e-04
#
# Epoch 00058: val_loss did not improve from 0.00064
# Epoch 59/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.2779e-04 - val_loss: 6.5771e-04
#
# Epoch 00059: val_loss did not improve from 0.00064
# Epoch 60/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 1.2537e-04 - val_loss: 6.8472e-04
#
# Epoch 00060: val_loss did not improve from 0.00064
# Epoch 61/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.2489e-04 - val_loss: 6.6595e-04
#
# Epoch 00061: val_loss did not improve from 0.00064
# Epoch 62/150
# 3424/3424 [==============================] - 1s 230us/step - loss: 1.2444e-04 - val_loss: 6.7167e-04
#
# Epoch 00062: val_loss did not improve from 0.00064
# Epoch 63/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 1.2162e-04 - val_loss: 6.6311e-04
#
# Epoch 00063: val_loss did not improve from 0.00064
# Epoch 64/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 1.2109e-04 - val_loss: 6.5676e-04
#
# Epoch 00064: val_loss did not improve from 0.00064
# Epoch 65/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.1589e-04 - val_loss: 6.7343e-04
#
# Epoch 00065: val_loss did not improve from 0.00064
# Epoch 66/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 1.1849e-04 - val_loss: 6.3660e-04
#
# Epoch 00066: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 67/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 1.1633e-04 - val_loss: 6.6918e-04
#
# Epoch 00067: val_loss did not improve from 0.00064
# Epoch 68/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 1.1410e-04 - val_loss: 6.7482e-04
#
# Epoch 00068: val_loss did not improve from 0.00064
# Epoch 69/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 1.1333e-04 - val_loss: 6.5843e-04
#
# Epoch 00069: val_loss did not improve from 0.00064
# Epoch 70/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 1.1114e-04 - val_loss: 6.6668e-04
#
# Epoch 00070: val_loss did not improve from 0.00064
# Epoch 71/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 1.1118e-04 - val_loss: 6.7517e-04
#
# Epoch 00071: val_loss did not improve from 0.00064
# Epoch 72/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.1010e-04 - val_loss: 6.7910e-04
#
# Epoch 00072: val_loss did not improve from 0.00064
# Epoch 73/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 1.1100e-04 - val_loss: 6.3822e-04
#
# Epoch 00073: val_loss did not improve from 0.00064
# Epoch 74/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.0788e-04 - val_loss: 6.3921e-04
#
# Epoch 00074: val_loss did not improve from 0.00064
# Epoch 75/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 1.0919e-04 - val_loss: 6.7378e-04
#
# Epoch 00075: val_loss did not improve from 0.00064
# Epoch 76/150
# 3424/3424 [==============================] - 1s 241us/step - loss: 1.0539e-04 - val_loss: 6.8101e-04
#
# Epoch 00076: val_loss did not improve from 0.00064
# Epoch 77/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 1.0465e-04 - val_loss: 6.6596e-04
#
# Epoch 00077: val_loss did not improve from 0.00064
# Epoch 78/150
# 3424/3424 [==============================] - 1s 242us/step - loss: 1.0760e-04 - val_loss: 6.5949e-04
#
# Epoch 00078: val_loss did not improve from 0.00064
# Epoch 79/150
# 3424/3424 [==============================] - 1s 246us/step - loss: 1.0591e-04 - val_loss: 6.6377e-04
#
# Epoch 00079: val_loss did not improve from 0.00064
# Epoch 80/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 1.0629e-04 - val_loss: 6.6184e-04
#
# Epoch 00080: val_loss did not improve from 0.00064
# Epoch 81/150
# 3424/3424 [==============================] - 1s 244us/step - loss: 1.0241e-04 - val_loss: 6.6797e-04
#
# Epoch 00081: val_loss did not improve from 0.00064
# Epoch 82/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.0118e-04 - val_loss: 6.7922e-04
#
# Epoch 00082: val_loss did not improve from 0.00064
# Epoch 83/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 1.0171e-04 - val_loss: 6.7375e-04
#
# Epoch 00083: val_loss did not improve from 0.00064
# Epoch 84/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.0148e-04 - val_loss: 6.5745e-04
#
# Epoch 00084: val_loss did not improve from 0.00064
# Epoch 85/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 1.0055e-04 - val_loss: 6.7339e-04
#
# Epoch 00085: val_loss did not improve from 0.00064
# Epoch 86/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 1.0095e-04 - val_loss: 6.5774e-04
#
# Epoch 00086: val_loss did not improve from 0.00064
# Epoch 87/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.7407e-05 - val_loss: 6.5616e-04
#
# Epoch 00087: val_loss did not improve from 0.00064
# Epoch 88/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 9.7042e-05 - val_loss: 6.6283e-04
#
# Epoch 00088: val_loss did not improve from 0.00064
# Epoch 89/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 9.6497e-05 - val_loss: 6.6586e-04
#
# Epoch 00089: val_loss did not improve from 0.00064
# Epoch 90/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 9.7487e-05 - val_loss: 6.7551e-04
#
# Epoch 00090: val_loss did not improve from 0.00064
# Epoch 91/150
# 3424/3424 [==============================] - 1s 231us/step - loss: 9.5157e-05 - val_loss: 6.5018e-04
#
# Epoch 00091: val_loss did not improve from 0.00064
# Epoch 92/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 9.6613e-05 - val_loss: 6.9192e-04
#
# Epoch 00092: val_loss did not improve from 0.00064
# Epoch 93/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 9.5391e-05 - val_loss: 6.5070e-04
#
# Epoch 00093: val_loss did not improve from 0.00064
# Epoch 94/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 9.5499e-05 - val_loss: 6.4873e-04
#
# Epoch 00094: val_loss did not improve from 0.00064
# Epoch 95/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 9.3488e-05 - val_loss: 6.5185e-04
#
# Epoch 00095: val_loss did not improve from 0.00064
# Epoch 96/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 9.2710e-05 - val_loss: 6.5981e-04
#
# Epoch 00096: val_loss did not improve from 0.00064
# Epoch 97/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 9.2117e-05 - val_loss: 6.6770e-04
#
# Epoch 00097: val_loss did not improve from 0.00064
# Epoch 98/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.1043e-05 - val_loss: 6.7227e-04
#
# Epoch 00098: val_loss did not improve from 0.00064
# Epoch 99/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 9.4501e-05 - val_loss: 6.7767e-04
#
# Epoch 00099: val_loss did not improve from 0.00064
# Epoch 100/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 9.5246e-05 - val_loss: 6.8270e-04
#
# Epoch 00100: val_loss did not improve from 0.00064
# Epoch 101/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 9.1951e-05 - val_loss: 6.7982e-04
#
# Epoch 00101: val_loss did not improve from 0.00064
# Epoch 102/150
# 3424/3424 [==============================] - 1s 240us/step - loss: 9.1455e-05 - val_loss: 6.5964e-04
#
# Epoch 00102: val_loss did not improve from 0.00064
# Epoch 103/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.9847e-05 - val_loss: 6.6562e-04
#
# Epoch 00103: val_loss did not improve from 0.00064
# Epoch 104/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 9.0496e-05 - val_loss: 6.5567e-04
#
# Epoch 00104: val_loss did not improve from 0.00064
# Epoch 105/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 8.7443e-05 - val_loss: 6.6623e-04
#
# Epoch 00105: val_loss did not improve from 0.00064
# Epoch 106/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 8.8059e-05 - val_loss: 6.5836e-04
#
# Epoch 00106: val_loss did not improve from 0.00064
# Epoch 107/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 9.0400e-05 - val_loss: 6.6444e-04
#
# Epoch 00107: val_loss did not improve from 0.00064
# Epoch 108/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 8.8490e-05 - val_loss: 6.5840e-04
#
# Epoch 00108: val_loss did not improve from 0.00064
# Epoch 109/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 8.7111e-05 - val_loss: 6.7362e-04
#
# Epoch 00109: val_loss did not improve from 0.00064
# Epoch 110/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.7402e-05 - val_loss: 6.6081e-04
#
# Epoch 00110: val_loss did not improve from 0.00064
# Epoch 111/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 8.7986e-05 - val_loss: 6.6420e-04
#
# Epoch 00111: val_loss did not improve from 0.00064
# Epoch 112/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 8.9785e-05 - val_loss: 6.7264e-04
#
# Epoch 00112: val_loss did not improve from 0.00064
# Epoch 113/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 8.7053e-05 - val_loss: 6.5542e-04
#
# Epoch 00113: val_loss did not improve from 0.00064
# Epoch 114/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.6667e-05 - val_loss: 6.5342e-04
#
# Epoch 00114: val_loss did not improve from 0.00064
# Epoch 115/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 8.5835e-05 - val_loss: 6.6787e-04
#
# Epoch 00115: val_loss did not improve from 0.00064
# Epoch 116/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 8.3402e-05 - val_loss: 6.6054e-04
#
# Epoch 00116: val_loss did not improve from 0.00064
# Epoch 117/150
# 3424/3424 [==============================] - 1s 239us/step - loss: 8.5802e-05 - val_loss: 6.6851e-04
#
# Epoch 00117: val_loss did not improve from 0.00064
# Epoch 118/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 8.8233e-05 - val_loss: 6.6244e-04
#
# Epoch 00118: val_loss did not improve from 0.00064
# Epoch 119/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 8.5988e-05 - val_loss: 6.8357e-04
#
# Epoch 00119: val_loss did not improve from 0.00064
# Epoch 120/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.5087e-05 - val_loss: 6.9517e-04
#
# Epoch 00120: val_loss did not improve from 0.00064
# Epoch 121/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.8051e-05 - val_loss: 6.7462e-04
#
# Epoch 00121: val_loss did not improve from 0.00064
# Epoch 122/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.4664e-05 - val_loss: 6.5312e-04
#
# Epoch 00122: val_loss did not improve from 0.00064
# Epoch 123/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.3328e-05 - val_loss: 6.8810e-04
#
# Epoch 00123: val_loss did not improve from 0.00064
# Epoch 124/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.4199e-05 - val_loss: 6.7607e-04
#
# Epoch 00124: val_loss did not improve from 0.00064
# Epoch 125/150
# 3424/3424 [==============================] - 1s 231us/step - loss: 8.3113e-05 - val_loss: 6.8429e-04
#
# Epoch 00125: val_loss did not improve from 0.00064
# Epoch 126/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 8.5861e-05 - val_loss: 6.7901e-04
#
# Epoch 00126: val_loss did not improve from 0.00064
# Epoch 127/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.6917e-05 - val_loss: 6.8695e-04
#
# Epoch 00127: val_loss did not improve from 0.00064
# Epoch 128/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.1182e-05 - val_loss: 6.7409e-04
#
# Epoch 00128: val_loss did not improve from 0.00064
# Epoch 129/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 8.4731e-05 - val_loss: 6.6640e-04
#
# Epoch 00129: val_loss did not improve from 0.00064
# Epoch 130/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 8.5231e-05 - val_loss: 6.8630e-04
#
# Epoch 00130: val_loss did not improve from 0.00064
# Epoch 131/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.2917e-05 - val_loss: 6.5717e-04
#
# Epoch 00131: val_loss did not improve from 0.00064
# Epoch 132/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 8.1382e-05 - val_loss: 6.8251e-04
#
# Epoch 00132: val_loss did not improve from 0.00064
# Epoch 133/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 8.1077e-05 - val_loss: 6.7129e-04
#
# Epoch 00133: val_loss did not improve from 0.00064
# Epoch 134/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 7.9741e-05 - val_loss: 6.8716e-04
#
# Epoch 00134: val_loss did not improve from 0.00064
# Epoch 135/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 8.3318e-05 - val_loss: 6.7479e-04
#
# Epoch 00135: val_loss did not improve from 0.00064
# Epoch 136/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 8.1558e-05 - val_loss: 6.5949e-04
#
# Epoch 00136: val_loss did not improve from 0.00064
# Epoch 137/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.1346e-05 - val_loss: 6.4993e-04
#
# Epoch 00137: val_loss did not improve from 0.00064
# Epoch 138/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 8.0920e-05 - val_loss: 6.8418e-04
#
# Epoch 00138: val_loss did not improve from 0.00064
# Epoch 139/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 7.9864e-05 - val_loss: 6.7397e-04
#
# Epoch 00139: val_loss did not improve from 0.00064
# Epoch 140/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 7.9310e-05 - val_loss: 6.7075e-04
#
# Epoch 00140: val_loss did not improve from 0.00064
# Epoch 141/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 8.0990e-05 - val_loss: 6.7185e-04
#
# Epoch 00141: val_loss did not improve from 0.00064
# Epoch 142/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 8.1310e-05 - val_loss: 6.8214e-04
#
# Epoch 00142: val_loss did not improve from 0.00064
# Epoch 143/150
# 3424/3424 [==============================] - 1s 235us/step - loss: 7.8954e-05 - val_loss: 6.7308e-04
#
# Epoch 00143: val_loss did not improve from 0.00064
# Epoch 144/150
# 3424/3424 [==============================] - 1s 238us/step - loss: 7.9402e-05 - val_loss: 6.7070e-04
#
# Epoch 00144: val_loss did not improve from 0.00064
# Epoch 145/150
# 3424/3424 [==============================] - 1s 234us/step - loss: 8.1723e-05 - val_loss: 6.7067e-04
#
# Epoch 00145: val_loss did not improve from 0.00064
# Epoch 146/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 8.4480e-05 - val_loss: 6.9666e-04
#
# Epoch 00146: val_loss did not improve from 0.00064
# Epoch 147/150
# 3424/3424 [==============================] - 1s 233us/step - loss: 7.8418e-05 - val_loss: 6.8185e-04
#
# Epoch 00147: val_loss did not improve from 0.00064
# Epoch 148/150
# 3424/3424 [==============================] - 1s 232us/step - loss: 7.8645e-05 - val_loss: 6.5983e-04
#
# Epoch 00148: val_loss did not improve from 0.00064
# Epoch 149/150
# 3424/3424 [==============================] - 1s 236us/step - loss: 7.6511e-05 - val_loss: 6.8696e-04
#
# Epoch 00149: val_loss did not improve from 0.00064
# Epoch 150/150
# 3424/3424 [==============================] - 1s 237us/step - loss: 7.7109e-05 - val_loss: 6.6030e-04
#
# Epoch 00150: val_loss did not improve from 0.00064

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
