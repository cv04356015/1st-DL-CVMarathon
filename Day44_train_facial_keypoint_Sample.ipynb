# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.
# 1.15.2

# %%
# !pip install keras==2.2.4
# !pip install keras==2.2.4
# Out:
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.18.5)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras==2.2.4) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4) (1.4.1)

# %%
import os
from google.colab import drive 
drive.mount('/content/drive') # 將 google drive 掛載在 colob，
# %cd "/content/drive/MyDrive/Colab/1st-DL-CVMarathon/Day042.Workdir"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab/1st-DL-CVMarathon/Day042.Workdir

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 15s 9ms/step - loss: 0.0077 - val_loss: 0.0025
#
# Epoch 00001: val_loss improved from inf to 0.00254, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 0.0021 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00254 to 0.00205, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 0.0014 - val_loss: 0.0021
#
# Epoch 00003: val_loss did not improve from 0.00205
# Epoch 4/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00205 to 0.00192, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00192 to 0.00181, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 0.0010 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00181 to 0.00172, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 8.7713e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00172 to 0.00159, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 7.1807e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00159 to 0.00142, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 6.3614e-04 - val_loss: 0.0012
#
# Epoch 00009: val_loss improved from 0.00142 to 0.00124, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 5.9005e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00124 to 0.00115, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 5.3613e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00115 to 0.00109, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 4.8463e-04 - val_loss: 0.0010
#
# Epoch 00012: val_loss improved from 0.00109 to 0.00103, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 4.5219e-04 - val_loss: 9.8215e-04
#
# Epoch 00013: val_loss improved from 0.00103 to 0.00098, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 4.2252e-04 - val_loss: 9.9220e-04
#
# Epoch 00014: val_loss did not improve from 0.00098
# Epoch 15/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 4.0556e-04 - val_loss: 9.0176e-04
#
# Epoch 00015: val_loss improved from 0.00098 to 0.00090, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 3.7953e-04 - val_loss: 8.8438e-04
#
# Epoch 00016: val_loss improved from 0.00090 to 0.00088, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 3.6919e-04 - val_loss: 8.8718e-04
#
# Epoch 00017: val_loss did not improve from 0.00088
# Epoch 18/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 3.5184e-04 - val_loss: 8.8514e-04
#
# Epoch 00018: val_loss did not improve from 0.00088
# Epoch 19/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 3.4036e-04 - val_loss: 8.7861e-04
#
# Epoch 00019: val_loss improved from 0.00088 to 0.00088, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 3.2056e-04 - val_loss: 8.7151e-04
#
# Epoch 00020: val_loss improved from 0.00088 to 0.00087, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 3.1315e-04 - val_loss: 8.5323e-04
#
# Epoch 00021: val_loss improved from 0.00087 to 0.00085, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 3.0002e-04 - val_loss: 8.0266e-04
#
# Epoch 00022: val_loss improved from 0.00085 to 0.00080, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.9643e-04 - val_loss: 8.6998e-04
#
# Epoch 00023: val_loss did not improve from 0.00080
# Epoch 24/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.9444e-04 - val_loss: 8.1370e-04
#
# Epoch 00024: val_loss did not improve from 0.00080
# Epoch 25/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 2.8119e-04 - val_loss: 8.7620e-04
#
# Epoch 00025: val_loss did not improve from 0.00080
# Epoch 26/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 2.7564e-04 - val_loss: 8.1321e-04
#
# Epoch 00026: val_loss did not improve from 0.00080
# Epoch 27/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 2.6418e-04 - val_loss: 8.3520e-04
#
# Epoch 00027: val_loss did not improve from 0.00080
# Epoch 28/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.6157e-04 - val_loss: 8.0159e-04
#
# Epoch 00028: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 2.5190e-04 - val_loss: 7.7555e-04
#
# Epoch 00029: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.4882e-04 - val_loss: 7.7230e-04
#
# Epoch 00030: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.4205e-04 - val_loss: 8.1101e-04
#
# Epoch 00031: val_loss did not improve from 0.00077
# Epoch 32/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 2.4170e-04 - val_loss: 8.2582e-04
#
# Epoch 00032: val_loss did not improve from 0.00077
# Epoch 33/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 2.3740e-04 - val_loss: 8.7016e-04
#
# Epoch 00033: val_loss did not improve from 0.00077
# Epoch 34/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.2720e-04 - val_loss: 7.8997e-04
#
# Epoch 00034: val_loss did not improve from 0.00077
# Epoch 35/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 2.2581e-04 - val_loss: 7.6934e-04
#
# Epoch 00035: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.1939e-04 - val_loss: 7.7929e-04
#
# Epoch 00036: val_loss did not improve from 0.00077
# Epoch 37/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 2.1657e-04 - val_loss: 7.9116e-04
#
# Epoch 00037: val_loss did not improve from 0.00077
# Epoch 38/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.1430e-04 - val_loss: 7.7029e-04
#
# Epoch 00038: val_loss did not improve from 0.00077
# Epoch 39/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 2.1096e-04 - val_loss: 7.9153e-04
#
# Epoch 00039: val_loss did not improve from 0.00077
# Epoch 40/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.0617e-04 - val_loss: 8.0202e-04
#
# Epoch 00040: val_loss did not improve from 0.00077
# Epoch 41/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.0675e-04 - val_loss: 8.7144e-04
#
# Epoch 00041: val_loss did not improve from 0.00077
# Epoch 42/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 2.0480e-04 - val_loss: 7.6150e-04
#
# Epoch 00042: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.9716e-04 - val_loss: 7.9113e-04
#
# Epoch 00043: val_loss did not improve from 0.00076
# Epoch 44/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.9187e-04 - val_loss: 7.4916e-04
#
# Epoch 00044: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.9365e-04 - val_loss: 7.8526e-04
#
# Epoch 00045: val_loss did not improve from 0.00075
# Epoch 46/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.8994e-04 - val_loss: 8.1038e-04
#
# Epoch 00046: val_loss did not improve from 0.00075
# Epoch 47/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.8867e-04 - val_loss: 7.7241e-04
#
# Epoch 00047: val_loss did not improve from 0.00075
# Epoch 48/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.8539e-04 - val_loss: 7.5142e-04
#
# Epoch 00048: val_loss did not improve from 0.00075
# Epoch 49/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.9129e-04 - val_loss: 7.8825e-04
#
# Epoch 00049: val_loss did not improve from 0.00075
# Epoch 50/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.8115e-04 - val_loss: 7.5693e-04
#
# Epoch 00050: val_loss did not improve from 0.00075
# Epoch 51/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.7958e-04 - val_loss: 7.3123e-04
#
# Epoch 00051: val_loss improved from 0.00075 to 0.00073, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.7743e-04 - val_loss: 7.9974e-04
#
# Epoch 00052: val_loss did not improve from 0.00073
# Epoch 53/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.7709e-04 - val_loss: 7.8014e-04
#
# Epoch 00053: val_loss did not improve from 0.00073
# Epoch 54/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 1.7156e-04 - val_loss: 7.2587e-04
#
# Epoch 00054: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 55/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.7307e-04 - val_loss: 7.7868e-04
#
# Epoch 00055: val_loss did not improve from 0.00073
# Epoch 56/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.7606e-04 - val_loss: 7.6830e-04
#
# Epoch 00056: val_loss did not improve from 0.00073
# Epoch 57/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.6942e-04 - val_loss: 7.4412e-04
#
# Epoch 00057: val_loss did not improve from 0.00073
# Epoch 58/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.6550e-04 - val_loss: 7.9651e-04
#
# Epoch 00058: val_loss did not improve from 0.00073
# Epoch 59/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.6574e-04 - val_loss: 7.3212e-04
#
# Epoch 00059: val_loss did not improve from 0.00073
# Epoch 60/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.6768e-04 - val_loss: 7.7581e-04
#
# Epoch 00060: val_loss did not improve from 0.00073
# Epoch 61/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.6129e-04 - val_loss: 7.7442e-04
#
# Epoch 00061: val_loss did not improve from 0.00073
# Epoch 62/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.6007e-04 - val_loss: 7.5408e-04
#
# Epoch 00062: val_loss did not improve from 0.00073
# Epoch 63/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.5854e-04 - val_loss: 7.6873e-04
#
# Epoch 00063: val_loss did not improve from 0.00073
# Epoch 64/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.5254e-04 - val_loss: 8.2890e-04
#
# Epoch 00064: val_loss did not improve from 0.00073
# Epoch 65/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.5450e-04 - val_loss: 7.9367e-04
#
# Epoch 00065: val_loss did not improve from 0.00073
# Epoch 66/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.5343e-04 - val_loss: 7.9887e-04
#
# Epoch 00066: val_loss did not improve from 0.00073
# Epoch 67/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.5335e-04 - val_loss: 7.4126e-04
#
# Epoch 00067: val_loss did not improve from 0.00073
# Epoch 68/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.5153e-04 - val_loss: 7.5952e-04
#
# Epoch 00068: val_loss did not improve from 0.00073
# Epoch 69/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.4974e-04 - val_loss: 7.2705e-04
#
# Epoch 00069: val_loss did not improve from 0.00073
# Epoch 70/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.4896e-04 - val_loss: 7.8300e-04
#
# Epoch 00070: val_loss did not improve from 0.00073
# Epoch 71/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.4433e-04 - val_loss: 7.6980e-04
#
# Epoch 00071: val_loss did not improve from 0.00073
# Epoch 72/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.4520e-04 - val_loss: 7.7812e-04
#
# Epoch 00072: val_loss did not improve from 0.00073
# Epoch 73/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.4578e-04 - val_loss: 8.5208e-04
#
# Epoch 00073: val_loss did not improve from 0.00073
# Epoch 74/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.4589e-04 - val_loss: 7.9798e-04
#
# Epoch 00074: val_loss did not improve from 0.00073
# Epoch 75/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.4324e-04 - val_loss: 7.5427e-04
#
# Epoch 00075: val_loss did not improve from 0.00073
# Epoch 76/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.4040e-04 - val_loss: 7.8663e-04
#
# Epoch 00076: val_loss did not improve from 0.00073
# Epoch 77/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.3831e-04 - val_loss: 7.6895e-04
#
# Epoch 00077: val_loss did not improve from 0.00073
# Epoch 78/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.3579e-04 - val_loss: 7.7026e-04
#
# Epoch 00078: val_loss did not improve from 0.00073
# Epoch 79/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.3345e-04 - val_loss: 7.8436e-04
#
# Epoch 00079: val_loss did not improve from 0.00073
# Epoch 80/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.3620e-04 - val_loss: 7.5888e-04
#
# Epoch 00080: val_loss did not improve from 0.00073
# Epoch 81/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.3209e-04 - val_loss: 7.4396e-04
#
# Epoch 00081: val_loss did not improve from 0.00073
# Epoch 82/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.3807e-04 - val_loss: 7.8581e-04
#
# Epoch 00082: val_loss did not improve from 0.00073
# Epoch 83/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.3398e-04 - val_loss: 7.6054e-04
#
# Epoch 00083: val_loss did not improve from 0.00073
# Epoch 84/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.3241e-04 - val_loss: 7.7214e-04
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.3121e-04 - val_loss: 7.2762e-04
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.2928e-04 - val_loss: 7.5724e-04
#
# Epoch 00086: val_loss did not improve from 0.00073
# Epoch 87/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.2709e-04 - val_loss: 7.8684e-04
#
# Epoch 00087: val_loss did not improve from 0.00073
# Epoch 88/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.2486e-04 - val_loss: 7.8222e-04
#
# Epoch 00088: val_loss did not improve from 0.00073
# Epoch 89/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.2671e-04 - val_loss: 7.4612e-04
#
# Epoch 00089: val_loss did not improve from 0.00073
# Epoch 90/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.2436e-04 - val_loss: 7.6730e-04
#
# Epoch 00090: val_loss did not improve from 0.00073
# Epoch 91/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 1.2305e-04 - val_loss: 7.7209e-04
#
# Epoch 00091: val_loss did not improve from 0.00073
# Epoch 92/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.2274e-04 - val_loss: 8.0887e-04
#
# Epoch 00092: val_loss did not improve from 0.00073
# Epoch 93/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.2308e-04 - val_loss: 7.6497e-04
#
# Epoch 00093: val_loss did not improve from 0.00073
# Epoch 94/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.2581e-04 - val_loss: 7.9321e-04
#
# Epoch 00094: val_loss did not improve from 0.00073
# Epoch 95/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.2228e-04 - val_loss: 7.8593e-04
#
# Epoch 00095: val_loss did not improve from 0.00073
# Epoch 96/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1563e-04 - val_loss: 7.5928e-04
#
# Epoch 00096: val_loss did not improve from 0.00073
# Epoch 97/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1554e-04 - val_loss: 8.2334e-04
#
# Epoch 00097: val_loss did not improve from 0.00073
# Epoch 98/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1694e-04 - val_loss: 7.4348e-04
#
# Epoch 00098: val_loss did not improve from 0.00073
# Epoch 99/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.1928e-04 - val_loss: 7.4947e-04
#
# Epoch 00099: val_loss did not improve from 0.00073
# Epoch 100/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.1406e-04 - val_loss: 7.6830e-04
#
# Epoch 00100: val_loss did not improve from 0.00073
# Epoch 101/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.1553e-04 - val_loss: 7.7281e-04
#
# Epoch 00101: val_loss did not improve from 0.00073
# Epoch 102/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.1231e-04 - val_loss: 7.4752e-04
#
# Epoch 00102: val_loss did not improve from 0.00073
# Epoch 103/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1119e-04 - val_loss: 7.5660e-04
#
# Epoch 00103: val_loss did not improve from 0.00073
# Epoch 104/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1078e-04 - val_loss: 7.7949e-04
#
# Epoch 00104: val_loss did not improve from 0.00073
# Epoch 105/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.1265e-04 - val_loss: 8.0177e-04
#
# Epoch 00105: val_loss did not improve from 0.00073
# Epoch 106/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1126e-04 - val_loss: 7.7330e-04
#
# Epoch 00106: val_loss did not improve from 0.00073
# Epoch 107/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.0791e-04 - val_loss: 7.3759e-04
#
# Epoch 00107: val_loss did not improve from 0.00073
# Epoch 108/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.0951e-04 - val_loss: 7.5277e-04
#
# Epoch 00108: val_loss did not improve from 0.00073
# Epoch 109/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.0902e-04 - val_loss: 7.5182e-04
#
# Epoch 00109: val_loss did not improve from 0.00073
# Epoch 110/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.0926e-04 - val_loss: 7.7633e-04
#
# Epoch 00110: val_loss did not improve from 0.00073
# Epoch 111/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.0852e-04 - val_loss: 7.7151e-04
#
# Epoch 00111: val_loss did not improve from 0.00073
# Epoch 112/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.0986e-04 - val_loss: 8.0050e-04
#
# Epoch 00112: val_loss did not improve from 0.00073
# Epoch 113/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.0618e-04 - val_loss: 7.7930e-04
#
# Epoch 00113: val_loss did not improve from 0.00073
# Epoch 114/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.0226e-04 - val_loss: 7.7037e-04
#
# Epoch 00114: val_loss did not improve from 0.00073
# Epoch 115/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 1.0426e-04 - val_loss: 7.5704e-04
#
# Epoch 00115: val_loss did not improve from 0.00073
# Epoch 116/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.0266e-04 - val_loss: 7.5592e-04
#
# Epoch 00116: val_loss did not improve from 0.00073
# Epoch 117/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.0528e-04 - val_loss: 7.5112e-04
#
# Epoch 00117: val_loss did not improve from 0.00073
# Epoch 118/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.0203e-04 - val_loss: 7.8898e-04
#
# Epoch 00118: val_loss did not improve from 0.00073
# Epoch 119/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.0256e-04 - val_loss: 8.0093e-04
#
# Epoch 00119: val_loss did not improve from 0.00073
# Epoch 120/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.0443e-04 - val_loss: 8.3515e-04
#
# Epoch 00120: val_loss did not improve from 0.00073
# Epoch 121/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.0274e-04 - val_loss: 7.7099e-04
#
# Epoch 00121: val_loss did not improve from 0.00073
# Epoch 122/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.0058e-04 - val_loss: 8.0605e-04
#
# Epoch 00122: val_loss did not improve from 0.00073
# Epoch 123/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 9.8948e-05 - val_loss: 7.7611e-04
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 9.8941e-05 - val_loss: 7.7567e-04
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 9.6474e-05 - val_loss: 7.9770e-04
#
# Epoch 00125: val_loss did not improve from 0.00073
# Epoch 126/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.0067e-04 - val_loss: 7.5282e-04
#
# Epoch 00126: val_loss did not improve from 0.00073
# Epoch 127/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.0021e-04 - val_loss: 7.2695e-04
#
# Epoch 00127: val_loss did not improve from 0.00073
# Epoch 128/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 9.7916e-05 - val_loss: 7.7334e-04
#
# Epoch 00128: val_loss did not improve from 0.00073
# Epoch 129/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.3661e-05 - val_loss: 7.5032e-04
#
# Epoch 00129: val_loss did not improve from 0.00073
# Epoch 130/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 9.3724e-05 - val_loss: 7.5620e-04
#
# Epoch 00130: val_loss did not improve from 0.00073
# Epoch 131/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 9.3485e-05 - val_loss: 7.2629e-04
#
# Epoch 00131: val_loss did not improve from 0.00073
# Epoch 132/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 9.2747e-05 - val_loss: 8.0387e-04
#
# Epoch 00132: val_loss did not improve from 0.00073
# Epoch 133/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.1729e-05 - val_loss: 7.6214e-04
#
# Epoch 00133: val_loss did not improve from 0.00073
# Epoch 134/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 9.1667e-05 - val_loss: 7.4944e-04
#
# Epoch 00134: val_loss did not improve from 0.00073
# Epoch 135/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 9.2661e-05 - val_loss: 8.0402e-04
#
# Epoch 00135: val_loss did not improve from 0.00073
# Epoch 136/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 9.5351e-05 - val_loss: 7.4665e-04
#
# Epoch 00136: val_loss did not improve from 0.00073
# Epoch 137/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 9.3862e-05 - val_loss: 7.2085e-04
#
# Epoch 00137: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 138/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 9.1402e-05 - val_loss: 7.3866e-04
#
# Epoch 00138: val_loss did not improve from 0.00072
# Epoch 139/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 9.1392e-05 - val_loss: 7.7370e-04
#
# Epoch 00139: val_loss did not improve from 0.00072
# Epoch 140/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 8.8964e-05 - val_loss: 7.3222e-04
#
# Epoch 00140: val_loss did not improve from 0.00072
# Epoch 141/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 8.9499e-05 - val_loss: 7.5858e-04
#
# Epoch 00141: val_loss did not improve from 0.00072
# Epoch 142/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 9.1366e-05 - val_loss: 7.3192e-04
#
# Epoch 00142: val_loss did not improve from 0.00072
# Epoch 143/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 8.9130e-05 - val_loss: 7.6835e-04
#
# Epoch 00143: val_loss did not improve from 0.00072
# Epoch 144/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 9.2185e-05 - val_loss: 7.2551e-04
#
# Epoch 00144: val_loss did not improve from 0.00072
# Epoch 145/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 8.8467e-05 - val_loss: 7.6608e-04
#
# Epoch 00145: val_loss did not improve from 0.00072
# Epoch 146/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 8.6298e-05 - val_loss: 7.8148e-04
#
# Epoch 00146: val_loss did not improve from 0.00072
# Epoch 147/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.1191e-05 - val_loss: 8.0385e-04
#
# Epoch 00147: val_loss did not improve from 0.00072
# Epoch 148/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 9.0661e-05 - val_loss: 8.1531e-04
#
# Epoch 00148: val_loss did not improve from 0.00072
# Epoch 149/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 8.4950e-05 - val_loss: 7.7912e-04
#
# Epoch 00149: val_loss did not improve from 0.00072
# Epoch 150/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 8.8203e-05 - val_loss: 7.5028e-04
#
# Epoch 00150: val_loss did not improve from 0.00072

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
